# %% [markdown]
# Exploratory Data Analysis (EDA) Summary

# %% [markdown]
# Overview:
# In this Exploratory Data Analysis (EDA), I analyzed a dataset for ELA and Math grades for several years during COVID-19. The dataset includes information such as DBN (District Borough Number), School Name, Category, Grade Metrics, and Year.

# %%
import os

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Key Variables:
#
# 'Borough': The district where the students live and go to school in.
#
# 'Category': The type of student being assessed
#
# 'Grade': The School grade which test was administered: All Grades, 3-8 grades
#
# 'Year': The year that the NYS standardized exam was taken.
#
# 'Category' : Reflects the set of students which were tested
#
# 'Number Tested' : The total number of students test
#
# 'Mean Scale Score' : The Average of total students tested
#
# '# Level 1' : Number of students who scored in Level 1 range
#
# '% Level 1' : Percentage of students who scored in Level 1 range
#
# '# Level 2': Number of students who scored in Level 2 range
#
# '% Level 2': Percentage of students who scored in Level 2 range
#
# '# Level 3': Number of students who scored in Level 3 range
#
# '% Level 3': Percentage of students who scored in Level 3 range
#
# '# Level 4': Number of students who scored in Level 4 range
#
# '% Level 4': Percentage of students who scored in Level 4 range
#
# '# Level 3+4': Number of students who scored in Level 3+4 range
#
# '% Level 3+4': Percentage of students who scored in Level 3+4 range

# %%
grades_df = pd.read_csv("/Users/rodoshikhan/Desktop/TKH Phase 2/2013-2019_English_Language_Arts__ELA__Test_Results_Borough_-_All_SWD_Ethnicity_Gender_Economic_Status_ELL_20240416.csv")

# %%
grades_df.head(5)
# Out:
#   Borough Grade  Year      Category  Number Tested  Mean Scale Score  \
# 0   BRONX     3  2013  All Students          15635               287
# 1   BRONX     3  2014  All Students          15647               285
# 2   BRONX     3  2015  All Students          15348               287
# 3   BRONX     3  2016  All Students          15291               298
# 4   BRONX     3  2017  All Students          14953               296
#
#    # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  % Level 3  \
# 0       7979       51.0       5105       32.7       2393       15.3
# 1       8021       51.3       4949       31.6       2504       16.0
# 2       7540       49.1       5061       33.0       2469       16.1
# 3       5725       37.4       5437       35.6       3658       23.9
# 4       6028       40.3       4713       31.5       3764       25.2
#
#    # Level 4  % Level 4  # Level 3+4  % Level 3+4
# 0        158        1.0         2551         16.3
# ...

# %%
grades_df.columns
# Out:
# Index(['Borough', 'Grade', 'Year', 'Category', 'Number Tested',
#        'Mean Scale Score', '# Level 1', '% Level 1', '# Level 2', '% Level 2',
#        '# Level 3', '% Level 3', '# Level 4', '% Level 4', '# Level 3+4',
#        '% Level 3+4'],
#       dtype='object')

# %%
grades_df['Year'].unique
# Out:
# <bound method Series.unique of 0      2013
# 1      2014
# 2      2015
# 3      2016
# 4      2017
#        ...
# 240    2015
# 241    2016
# 242    2017
# 243    2018
# 244    2019
# Name: Year, Length: 245, dtype: int64>

# %%
grades_df.isnull().sum()
# Out:
# Borough             0
# Grade               0
# Year                0
# Category            0
# Number Tested       0
# Mean Scale Score    0
# # Level 1           0
# % Level 1           0
# # Level 2           0
# % Level 2           0
# # Level 3           0
# % Level 3           0
# # Level 4           0
# % Level 4           0
# # Level 3+4         0
# % Level 3+4         0
# dtype: int64

# %%
grades_df.describe()
# Out:
#               Year  Number Tested  Mean Scale Score     # Level 1   % Level 1  \
# count   245.000000     245.000000        245.000000    245.000000  245.000000
# mean   2016.000000   22834.489796        386.955102   6652.808163   28.212245
# std       2.004094   27959.105192        136.101133   8642.194963    9.365677
# min    2013.000000    3921.000000        279.000000    465.000000   11.800000
# 25%    2014.000000    7958.000000        300.000000   1968.000000   21.700000
# 50%    2016.000000   15348.000000        305.000000   4704.000000   27.400000
# 75%    2018.000000   20250.000000        594.000000   6627.000000   33.200000
# max    2019.000000  125059.000000        606.000000  45756.000000   51.800000
#
#           # Level 2   % Level 2     # Level 3   % Level 3     # Level 4  \
# count    245.000000  245.000000    245.000000  245.000000    245.000000
# mean    7750.506122   33.639184   5444.073469   24.326122   2987.102041
# ...

# %%
grades_df.dropna(inplace=True)

# %%
grades_df['Mean Scale Score'].unique()
# Out:
# array([287, 285, 298, 296, 593, 594, 297, 288, 286, 289, 282, 284, 591,
#        283, 293, 595, 279, 295, 300, 294, 299, 309, 308, 601, 600, 602,
#        304, 303, 305, 311, 603, 291, 306, 307, 301, 315, 604, 605, 312,
#        316, 606, 302, 317, 314, 313, 310])

# %%
grades_df[['Mean Scale Score', 'Grade' , 'Year', 'Borough']]
# Out:
#      Mean Scale Score       Grade  Year        Borough
# 0                 287           3  2013          BRONX
# 1                 285           3  2014          BRONX
# 2                 287           3  2015          BRONX
# 3                 298           3  2016          BRONX
# 4                 296           3  2017          BRONX
# ..                ...         ...   ...            ...
# 240               305  All Grades  2015  STATEN ISLAND
# 241               310  All Grades  2016  STATEN ISLAND
# 242               312  All Grades  2017  STATEN ISLAND
# 243               604  All Grades  2018  STATEN ISLAND
# 244               603  All Grades  2019  STATEN ISLAND
#
# [245 rows x 4 columns]

# %%
grades_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32765 entries, 0 to 32764
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed Column    32765 non-null  object
#  1   DBN               32765 non-null  object
#  2   School Name       32765 non-null  object
#  3   Grade             32765 non-null  object
#  4   Year              32765 non-null  int64
#  5   Category          32765 non-null  object
#  6   Number Tested     32765 non-null  int64
#  7   Mean Scale Score  32765 non-null  int64
#  8   # Level 1         32765 non-null  int64
#  9   % Level 1         32765 non-null  float64
#  10  # Level 2         32765 non-null  int64
#  11  % Level 2         32765 non-null  float64
#  12  # Level 3         32765 non-null  int64
#  13  % Level 3         32765 non-null  float64
#  14  # Level 4         32765 non-null  int64
#  15  % Level 4         32765 non-null  float64
# ...

# %%
#creating a variable for the different grades
grades_column = ['# Level 1', '# Level 2', '# Level 3', '# Level 4', '# Level 3+4']
# Extracting a subset of the dataframe containing only the numerical columns
testgrades_df = grades_df[grade_columns]

# Calculating the correlation matrix for the numerical columns
corr_matrix = testgrades_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='magma', fmt=".2f")
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Borough', data='grades_column')
plt.title('Distribution of Grades by Borough')
plt.xlabel('Borough')
plt.ylabel('Grades')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 sns.countplot(x='Borough', data='grades_column')
#       3 plt.title('Distribution of Grades by Borough')
#       4 plt.xlabel('Borough')
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
# ...

# %%
# Plotting the graph
plt.figure(figsize=(15, 10))
plt.plot(grades_df.index, grades_df['% Level 1'], marker='o', label='Level 1')
plt.plot(grades_df.index, grades_df['% Level 2'], marker='o', label='Level 2')
plt.plot(grades_df, grades_df['% Level 3'], marker='o', label='Level 3')
plt.plot(grades_df.index, grades_df['% Level 4'], marker='o', label='Level 4')

plt.title('Percentage of Students at Four Distinct Achievement Levels')
plt.xlabel('Grade')
plt.ylabel('Percentage of Students')
plt.legend(title='Different Achievement Levels')
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       3 plt.plot(grades_df.index, grades_df['% Level 1'], marker='o', label='Level 1')
#       4 plt.plot(grades_df.index, grades_df['% Level 2'], marker='o', label='Level 2')
# ----> 5 plt.plot(grades_df, grades_df['% Level 3'], marker='o', label='Level 3')
#       6 plt.plot(grades_df.index, grades_df['% Level 4'], marker='o', label='Level 4')
#       8 plt.title('Percentage of Students at Four Distinct Achievement Levels')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
# ...

# %%
#plotting for students who got Grade 4 Level Achievement
plt.figure(figsize=(20, 12))
plt.plot(grades_df['% Level 4'], marker='o', linestyle='-', label='Level 4')

plt.title('Percentage of Students at Level 4 Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
#plotting for students who got Grade 3 Level Achievement
plt.figure(figsize=(20, 12))
plt.plot(grades_df['% Level 3'], marker='o', linestyle='-', label='Level 3')

plt.title('Percentage of Students at Level 3 Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
#plotting for students who got Grade 2 Level Achievement
plt.figure(figsize=(20, 12))
plt.plot(grades_df['% Level 2'], marker='o', linestyle='-', label='Level 2')

plt.title('Percentage of Students at Level 2 Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
#plotting for students who got Grade 1 Level Achievement
plt.figure(figsize=(20, 12))
plt.plot(grades_df['% Level 1'], marker='o', linestyle='-', label='Level 1')

plt.title('Percentage of Students at Level 1 Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
grades_df.index.unique()
# Out:
# RangeIndex(start=0, stop=245, step=1)

# %%
mathtest_df = pd.read_csv("/Users/rodoshikhan/Desktop/TKH Phase 2/NYCeducation-duringCOVID/data/Math_Test_Results_2013-2023_20240515.csv")
# Out:
# /var/folders/43/mc_jwg151jq0f2gdkv0rcmg00000gn/T/ipykernel_2989/332896335.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   mathtest_df = pd.read_csv("/Users/rodoshikhan/Desktop/TKH Phase 2/NYCeducation-duringCOVID/data/Math_Test_Results_2013-2023_20240515.csv")

# %%
mathtest_df.head()
# Out:
#   Report Category Geographic Subdivision School Name Grade  Year  \
# 0        Citywide               Citywide         NaN     3  2023
# 1        Citywide               Citywide         NaN     4  2023
# 2        Citywide               Citywide         NaN     5  2023
# 3        Citywide               Citywide         NaN     6  2023
# 4        Citywide               Citywide         NaN     7  2023
#
#   Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# 0     All Students          51866              454        8193        15.8
# 1     All Students          53195              453       13460        25.3
# 2     All Students          55137              452       15055        27.3
# 3     All Students          53519              450       16049        30.0
# 4     All Students          54141              454       11723        21.7
#
#   Num Level 2 Pct Level 2 Num Level 3 Pct Level 3 Num Level 4 Pct Level 4  \
# ...

# %%
mathtest_df.columns
# Out:
# Index(['Report Category', 'Geographic Subdivision', 'School Name', 'Grade',
#        'Year', 'Student Category', 'Number Tested', 'Mean Scale Score',
#        'Num Level 1', 'Pct Level 1', 'Num Level 2', 'Pct Level 2',
#        'Num Level 3', 'Pct Level 3', 'Num Level 4', 'Pct Level 4',
#        'Num Level 3 and 4', 'Pct Level 3 and 4'],
#       dtype='object')

# %%
mathtest_df['Year'].unique()
# Out:
# array([2023, 2022, 2019, 2018, 2017, 2016, 2015, 2014, 2013])

# %%
mathtest_df['Mean Scale Score'].unique()
# Out:
# array(['454', '453', '452', '450', '446', '597', '595', '596', '598',
#        '600', '601', '599', '307', '303', '300', '305', '292', '304',
#        '306', '293', '302', '308', '301', '299', '298', '296', '297',
#        '458', '438', '457', '436', '435', '455', '432', '459', '430',
#        '456', '584', '581', '602', '582', '603', '587', '604', '586',
#        '605', '585', '583', '313', '280', '311', '273', '314', '278',
#        '310', '266', '263', '272', '274', '312', '270', '264', '279',
#        '309', '275', '316', '269', '265', '315', '267', '277', '268',
#        '271', '469', '445', '444', '468', '465', '471', '442', '470',
#        '466', '441', '451', '464', '472', '440', '463', '475', '443',
#        '467', '609', '589', '611', '608', '606', '612', '588', '607',
#        '593', '610', '592', '613', '591', '594', '614', '615', '616',
#        '617', '590', '331', '295', '329', '324', '330', '286', '291',
# ...

# %%
mathtest_df['Num Level 3 and 4'].unique()
# Out:
# array(['28518', '27837', '27841', ..., '8854', '1827', '9385'],
#       dtype=object)

# %%
mathtest_df[(mathtest_df['Geographic Subdivision'] == 'Citywide') &
            (mathtest_df['Grade'] == 'All Grades') &
            (mathtest_df['Student Category'] == 'All Students') 
            ].sample(5)
# Out:
#    Report Category Geographic Subdivision School Name       Grade  Year  \
# 20        Citywide               Citywide         NaN  All Grades  2019
# 48        Citywide               Citywide         NaN  All Grades  2015
# 6         Citywide               Citywide         NaN  All Grades  2023
# 55        Citywide               Citywide         NaN  All Grades  2014
# 41        Citywide               Citywide         NaN  All Grades  2016
#
#    Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# 20     All Students         383235              600      115309        30.1
# 48     All Students         399122              302      133531        33.5
# 6      All Students         301550              452       78338        26.0
# 55     All Students         407484              301      138253        33.9
# 41     All Students         396980              303      129742        32.7
#
# ...

# %%
math_results =  mathtest_df[
    (mathtest_df['Geographic Subdivision'] == 'Citywide') &
    (mathtest_df['Grade'] == 'All Grades') &
    (mathtest_df['Student Category'] == 'All Students') 
].copy()

math_results.set_index('Year', inplace=True)

# %%
math_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 2023 to 2013
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Report Category         9 non-null      object
#  1   Geographic Subdivision  9 non-null      object
#  2   School Name             0 non-null      object
#  3   Grade                   9 non-null      object
#  4   Student Category        9 non-null      object
#  5   Number Tested           9 non-null      int64
#  6   Mean Scale Score        9 non-null      object
#  7   Num Level 1             9 non-null      object
#  8   Pct Level 1             9 non-null      object
#  9   Num Level 2             9 non-null      object
#  10  Pct Level 2             9 non-null      object
#  11  Num Level 3             9 non-null      object
#  12  Pct Level 3             9 non-null      object
#  13  Num Level 4             9 non-null      object
# ...

# %%
math_results[(math_results['Geographic Subdivision'] == 'Citywide') & 
        (math_results['Grade'] == 'All Grades') & 
        (math_results['Student Category'] == 'All Students')
        ].head(5)
# Out:
#      Report Category Geographic Subdivision School Name       Grade  \
# Year
# 2023        Citywide               Citywide         NaN  All Grades
# 2022        Citywide               Citywide         NaN  All Grades
# 2019        Citywide               Citywide         NaN  All Grades
# 2018        Citywide               Citywide         NaN  All Grades
# 2017        Citywide               Citywide         NaN  All Grades
#
#      Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# Year
# 2023     All Students         301550              452       78338        26.0
# 2022     All Students         303456              596      116979        38.5
# 2019     All Students         383235              600      115309        30.1
# 2018     All Students         388307              599      126105        32.5
# 2017     All Students         393744              303      130777        33.2
#
# ...

# %%
citywide_results = math_results[
    (math_results['Geographic Subdivision'] == 'Citywide') & 
    (math_results['Grade'] == 'All Grades') & 
    (math_results['Student Category'] == 'All Students') 
].copy()

# %%
columns_to_convert = [
    "Mean Scale Score",
    "Num Level 1",
    "Pct Level 1",
    "Num Level 2",
    "Pct Level 2",
    "Num Level 3",
    "Pct Level 3",
    "Num Level 4",
    "Pct Level 4",
    "Num Level 3 and 4",
    "Pct Level 3 and 4"
]

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(citywide_results.index, citywide_results['Pct Level 1'], marker='o', label='Pct Level 1')
plt.plot(citywide_results.index, citywide_results['Pct Level 2'], marker='o', label='Pct Level 2')
plt.plot(citywide_results.index, citywide_results['Pct Level 3'], marker='o', label='Pct Level 3')
plt.plot(citywide_results.index, citywide_results['Pct Level 4'], marker='o', label='Pct Level 4')

plt.title('Percentage of Students by Achievement Levels Over Years (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(citywide_results.index, citywide_results['Pct Level 1'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 1 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 1')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(citywide_results.index, citywide_results['Pct Level 2'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 2 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(citywide_results.index, citywide_results['Pct Level 3'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 3 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 3')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(citywide_results.index, citywide_results['Pct Level 4'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 4 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 4')
plt.grid(True)
plt.show()

# %%
engtest_df = pd.read_csv("/Users/rodoshikhan/Desktop/TKH Phase 2/NYCeducation-duringCOVID/data/English_Language_Arts__ELA__Test_Results_2013-2023_20240501.csv")

# %%
engtest_df.columns
# Out:
# Index(['Report Category', 'Geographic Subdivision', 'School Name', 'Grade',
#        'Year', 'Student Category', 'Number Tested', 'Mean Scale Score',
#        'Num Level 1', 'Pct Level 1', 'Num Level 2', 'Pct Level 2',
#        'Num Level 3', 'Pct Level 3', 'Num Level 4', 'Pct Level 4',
#        'Num Level 3 and 4', 'Pct Level 3 and 4'],
#       dtype='object')

# %%
engtest_df.head()
# Out:
#   Report Category Geographic Subdivision School Name Grade  Year  \
# 0        Citywide               Citywide         NaN     3  2023
# 1        Citywide               Citywide         NaN     4  2023
# 2        Citywide               Citywide         NaN     5  2023
# 3        Citywide               Citywide         NaN     6  2023
# 4        Citywide               Citywide         NaN     7  2023
#
#   Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# 0     All Students          49453              447       14225        28.8
# 1     All Students          51008              450       10679        20.9
# 2     All Students          53235              449       12486        23.5
# 3     All Students          51996              447       13237        25.5
# 4     All Students          53472              450       12976        24.3
#
#   Num Level 2 Pct Level 2 Num Level 3 Pct Level 3 Num Level 4 Pct Level 4  \
# ...

# %%
engtest_df.sample(10)
# Out:
#        Report Category Geographic Subdivision  \
# 71427           School                 27Q043
# 282704          School                 02M442
# 495389          School                 14K577
# 21255         District                      9
# 193249          School                 10X056
# 186498          School                 08X467
# 538665          School                 31R039
# 460639          School                 02M059
# 18414         District                      1
# 309718          School                 08X304
#
#                                      School Name       Grade  Year  \
# 71427                                   P.S. 043           4  2015
# 282704  BALLET TECH, NYC PUBLIC SCHOOL FOR DANCE           8  2017
# 495389              CONSELYEA PREPARATORY SCHOOL           7  2019
# 21255                                        NaN  All Grades  2022
# 193249                  P.S. 056 NORWOOD HEIGHTS           4  2014
# ...

# %%
engtest_df['Year'].unique()
# Out:
# array([2023, 2022, 2019, 2018, 2017, 2016, 2015, 2014, 2013])

# %%
engtest_df['Mean Scale Score'].unique()
# Out:
# array(['447', '450', '449', '454', '600', '597', '602', '603', '606',
#        '599', '601', '308', '303', '299', '310', '306', '309', '301',
#        '304', '305', '298', 's', '295', '296', '297', '294', '292', '442',
#        '459', '446', '463', '445', '460', '444', '461', '451', '596',
#        '610', '592', '609', '598', '611', '614', '604', '595', '612',
#        '302', '323', '322', '318', '314', '319', '320', '321', '293',
#        '313', '300', '315', '317', '312', '290', '307', '291', '311',
#        '316', '289', '288', '430', '429', '453', '428', '423', '455',
#        '457', '426', '456', '427', '452', '588', '581', '607', '585',
#        '583', '605', '608', '577', '586', '579', '576', '275', '578',
#        '580', '584', '582', '282', '276', '263', '261', '271', '269',
#        '280', '279', '258', '266', '270', '272', '259', '260', '265',
#        '264', '256', '441', '439', '462', '443', '466', '440', '465',
# ...

# %%
engtest_df['Geographic Subdivision'].unique()
# Out:
# array(['Citywide', '07X277', '07X584', ..., '32K384', '32K554', '32K562'],
#       dtype=object)

# %%
engtest_df[(engtest_df['Geographic Subdivision'] == 'Citywide') &
            (engtest_df['Grade'] == 'All Grades') &
            (engtest_df['Student Category'] == 'All Students') 
            ].sample(5)
# Out:
#    Report Category Geographic Subdivision School Name       Grade  Year  \
# 34        Citywide               Citywide         NaN  All Grades  2017
# 13        Citywide               Citywide         NaN  All Grades  2022
# 6         Citywide               Citywide         NaN  All Grades  2023
# 63        Citywide               Citywide         NaN  All Grades  2013
# 56        Citywide               Citywide         NaN  All Grades  2014
#
#    Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# 34     All Students         397448              306      102571        25.8
# 13     All Students         322720              602       72571        22.5
# 6      All Students         313083              450       71620        22.9
# 63     All Students         415257              296      151196        36.4
# 56     All Students         411259              296      142758        34.7
#
# ...

# %%
eng_results =  engtest_df[
    (engtest_df['Geographic Subdivision'] == 'Citywide') &
    (engtest_df['Grade'] == 'All Grades') &
    (engtest_df['Student Category'] == 'All Students') 
].copy()

eng_results.set_index('Year', inplace=True)

# %%
eng_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 2023 to 2013
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Report Category         9 non-null      object
#  1   Geographic Subdivision  9 non-null      object
#  2   School Name             0 non-null      object
#  3   Grade                   9 non-null      object
#  4   Student Category        9 non-null      object
#  5   Number Tested           9 non-null      int64
#  6   Mean Scale Score        9 non-null      object
#  7   Num Level 1             9 non-null      object
#  8   Pct Level 1             9 non-null      object
#  9   Num Level 2             9 non-null      object
#  10  Pct Level 2             9 non-null      object
#  11  Num Level 3             9 non-null      object
#  12  Pct Level 3             9 non-null      object
#  13  Num Level 4             9 non-null      object
# ...

# %%
eng_results[(eng_results['Geographic Subdivision'] == 'Citywide') & 
        (eng_results['Grade'] == 'All Grades') & 
        (eng_results['Student Category'] == 'All Students')
        ].head(5)
# Out:
#      Report Category Geographic Subdivision School Name       Grade  \
# Year
# 2023        Citywide               Citywide         NaN  All Grades
# 2022        Citywide               Citywide         NaN  All Grades
# 2019        Citywide               Citywide         NaN  All Grades
# 2018        Citywide               Citywide         NaN  All Grades
# 2017        Citywide               Citywide         NaN  All Grades
#
#      Student Category  Number Tested Mean Scale Score Num Level 1 Pct Level 1  \
# Year
# 2023     All Students         313083              450       71620        22.9
# 2022     All Students         322720              602       72571        22.5
# 2019     All Students         392460              600       96610        24.6
# 2018     All Students         396502              601       93331        23.5
# 2017     All Students         397448              306      102571        25.8
#
# ...

# %%
geo_results = eng_results[
    (eng_results['Geographic Subdivision'] == 'Citywide') & 
    (eng_results['Grade'] == 'All Grades') & 
    (eng_results['Student Category'] == 'All Students') 
].copy()

# %%
columns_to_convert = [
    "Mean Scale Score",
    "Num Level 1",
    "Pct Level 1",
    "Num Level 2",
    "Pct Level 2",
    "Num Level 3",
    "Pct Level 3",
    "Num Level 4",
    "Pct Level 4",
    "Num Level 3 and 4",
    "Pct Level 3 and 4"
]

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(geo_results.index, geo_results['Pct Level 1'], marker='o', label='Pct Level 1')
plt.plot(geo_results.index, geo_results['Pct Level 2'], marker='o', label='Pct Level 2')
plt.plot(geo_results.index, geo_results['Pct Level 3'], marker='o', label='Pct Level 3')
plt.plot(geo_results.index, geo_results['Pct Level 4'], marker='o', label='Pct Level 4')

plt.title('Percentage of Students by Achievement Levels Over Years (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Achievement Level')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(geo_results.index, geo_results['Pct Level 1'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 1 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 1')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(geo_results.index, geo_results['Pct Level 2'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 2 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(geo_results.index, geo_results['Pct Level 3'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 3 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 3')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(geo_results.index, geo_results['Pct Level 4'], marker='o', linestyle='-')
plt.title('Percentage of Students at Level 4 Over Time (Citywide)')
plt.xlabel('Year')
plt.ylabel('Percentage at Level 4')
plt.grid(True)
plt.show()
